# %%
import pandas as pd
import pickle
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-01-04 15:28:41.353668: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-04 15:28:41.353685: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
metric = 'CKA'
selection = 'All'
method = 'HC'

f = 'local_logs/ExtraSensory/CKA-(-1)-HC-All-0.5/evaluate/acc_60clients_10clusters.csv'

acc =  pd.read_csv(f , names=['rounds', 'client', 'acc', 'loss'])

sns.lineplot(acc.groupby('rounds').mean(), y = 'acc', x = 'rounds',
                linewidth = 2.5, legend='brief')

f = 'local_logs/ExtraSensory/CKA-(-1)-HC-All-0.5/evaluate/acc_60clients_1clusters.csv'

acc =  pd.read_csv(f , names=['rounds', 'client', 'acc', 'loss'])

sns.lineplot(acc.groupby('rounds').mean(), y = 'acc', x = 'rounds',
                linewidth = 2.5, legend='brief')

f = 'local_logs/ExtraSensory/CKA-(-1)-HC-All-0.5/evaluate/acc_60clients_20clusters.csv'

acc =  pd.read_csv(f , names=['rounds', 'client', 'acc', 'loss'])

sns.lineplot(acc.groupby('rounds').mean(), y = 'acc', x = 'rounds',
                linewidth = 2.5, legend='brief')

f = 'local_logs/ExtraSensory/CKA-(-1)-HC-All-0.5/evaluate/acc_60clients_50clusters.csv'

acc =  pd.read_csv(f , names=['rounds', 'client', 'acc', 'loss'])

sns.lineplot(acc.groupby('rounds').mean(), y = 'acc', x = 'rounds',
                linewidth = 2.5, legend='brief')

plt.xlabel('Communication Rounds', size = 14)
plt.ylabel('Test Accuracy', size  = 14)
# Out:
# Text(0, 0.5, 'Test Accuracy')
