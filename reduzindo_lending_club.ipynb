# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(123456)

# %%
rejected = pd.read_csv('/home/gabrieltalasso/Downloads/rejected_2007_to_2018Q4.csv.gz', skiprows=lambda x: x > 0 and np.random.random() >=0.05)
rejected.head()
# Out:
#    Amount Requested Application Date    Loan Title  Risk_Score  \
# 0            4000.0       2007-05-30        sparks       671.0
# 1            3000.0       2007-06-01           cdc       556.0
# 2            1100.0       2007-06-04       MATTHEW       551.0
# 3            1000.0       2007-06-05  queenlurline         0.0
# 4            1000.0       2007-06-05      Raistlan       647.0
#
#   Debt-To-Income Ratio Zip Code State Employment Length  Policy Code
# 0                36.8%    630xx    MO          < 1 year          0.0
# 1               20.91%    786xx    TX            1 year          0.0
# 2                0.72%    334xx    FL           4 years          0.0
# 3                0.86%    846xx    UT          < 1 year          0.0
# 4                7.21%    980xx    WA           7 years          0.0

# %%
accepted = pd.read_csv('/home/gabrieltalasso/Downloads/accepted_2007_to_2018Q4.csv.gz', skiprows=lambda x: x > 0 and np.random.random() >=0.05)
accepted.head()
# Out:
# /tmp/ipykernel_3941916/1645785205.py:1: DtypeWarning: Columns (19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   accepted = pd.read_csv('/home/gabrieltalasso/Downloads/accepted_2007_to_2018Q4.csv.gz', skiprows=lambda x: x > 0 and np.random.random() >=0.05)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68566886        NaN    29900.0      29900.0          29900.0   60 months
# 1  68527009        NaN    20000.0      20000.0          20000.0   36 months
# 2  68436934        NaN    23975.0      23975.0          23975.0   60 months
# 3  68547679        NaN    18500.0      18500.0          18500.0   60 months
# 4  68426699        NaN    20000.0      20000.0          20000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     12.88       678.49     C        C2  ...                            NaN
# ...

# %%
np.array(accepted.columns)
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'fico_range_low',
#        'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
#        'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'last_fico_range_high', 'last_fico_range_low',
# ...

# %%
#principais caracteristicas do dataset - dados faltantes, proporções etc
#como foi a politica de credito?
#o que significa o risk score
#aplicar AIF360 no conjunto
